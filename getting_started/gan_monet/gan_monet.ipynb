# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from skimage import io

import tensorflow as tf
# Out:
# 2024-05-24 22:26:30.058184: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
path_monet_jpg = '/home/sjt/space/github/kaggle/data/gan_monet/monet_jpg'
path_monet_tfrec = '/home/sjt/space/github/kaggle/data/gan_monet/monet_tfrec'
path_photo_jpg = '/home/sjt/space/github/kaggle/data/gan_monet/photo_jpg'
path_photo_tfrec = '/home/sjt/space/github/kaggle/data/gan_monet/photo_tfrec'

img_pathlist = os.listdir(path_monet_jpg)
img_pathlist = [path_monet_jpg+'/'+i for i in img_pathlist]

monet_tfrec_pathlist = os.listdir(path_monet_tfrec)
monet_tfrec_pathlist = [path_monet_tfrec+'/'+i for i in monet_tfrec_pathlist]

# %%
plt.imshow(io.imread(img_pathlist[0]))

# %%
monet_tfrec = tf.data.TFRecordDataset(monet_tfrec_pathlist)

# %%
monet_tfrec_pathlist
# Out:
# ['/home/sjt/space/github/kaggle/data/gan_monet/monet_tfrec/monet04-60.tfrec',
#  '/home/sjt/space/github/kaggle/data/gan_monet/monet_tfrec/monet16-60.tfrec',
#  '/home/sjt/space/github/kaggle/data/gan_monet/monet_tfrec/monet00-60.tfrec',
#  '/home/sjt/space/github/kaggle/data/gan_monet/monet_tfrec/monet08-60.tfrec',
#  '/home/sjt/space/github/kaggle/data/gan_monet/monet_tfrec/monet12-60.tfrec']

# %%
monet_tfrec
# Out:
# <TFRecordDatasetV2 element_spec=TensorSpec(shape=(), dtype=tf.string, name=None)>

# %%
for i in monet_tfrec.take(2):
    e = tf.train.Example()
    e.ParseFromString(i.numpy())
    print(e)
# Out:
# features {
#   feature {
#     key: "image"
#     value {
#       bytes_list {
# ...
