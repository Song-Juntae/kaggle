# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path_train = '/home/sjt/space/github/kaggle/data/facial_keypoints_detection/training.csv'
path_test = '/home/sjt/space/github/kaggle/data/facial_keypoints_detection/test.csv'
path_IdLookupTable = '/home/sjt/space/github/kaggle/data/facial_keypoints_detection/IdLookupTable.csv'

train = pd.read_csv(path_train)
Id_Lookup_Table = pd.read_csv(path_IdLookupTable)
test = pd.read_csv(path_test)

# %%
train.loc[0]
# Out:
# left_eye_center_x                                                    66.033564
# left_eye_center_y                                                    39.002274
# right_eye_center_x                                                   30.227008
# right_eye_center_y                                                   36.421678
# left_eye_inner_corner_x                                              59.582075
# left_eye_inner_corner_y                                              39.647423
# left_eye_outer_corner_x                                              73.130346
# left_eye_outer_corner_y                                              39.969997
# right_eye_inner_corner_x                                             36.356571
# right_eye_inner_corner_y                                             37.389402
# right_eye_outer_corner_x                                             23.452872
# right_eye_outer_corner_y                                             37.389402
# ...

# %%
plt.imshow(np.reshape([0 if i == '' else float(i) for i in train.loc[137]['Image'].split(' ')], (96,96)), cmap='gray')
