# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path_train = '/home/sjt/space/github/kaggle/data/santander_customer_transaction_prediction/train.csv'
path_test = '/home/sjt/space/github/kaggle/data/santander_customer_transaction_prediction/test.csv'

train = pd.read_csv(path_train)
train_y = train.pop('target')
test = pd.read_csv(path_test)

# %%
train
# Out:
#              ID_code    var_0   var_1    var_2   var_3    var_4    var_5  \
# 0            train_0   8.9255 -6.7863  11.9081  5.0930  11.4607  -9.2834
# 1            train_1  11.5006 -4.1473  13.8588  5.3890  12.3622   7.0433
# 2            train_2   8.6093 -2.7457  12.0805  7.8928  10.5825  -9.0837
# 3            train_3  11.0604 -2.1518   8.9522  7.1957  12.5846  -1.8361
# 4            train_4   9.8369 -1.4834  12.8746  6.6375  12.2772   2.4486
# ...              ...      ...     ...      ...     ...      ...      ...
# 199995  train_199995  11.4880 -0.4956   8.2622  3.5142  10.3404  11.6081
# 199996  train_199996   4.9149 -2.4484  16.7052  6.6345   8.3096 -10.5628
# 199997  train_199997  11.2232 -5.0518  10.5127  5.6456   9.3410  -5.4086
# 199998  train_199998   9.7148 -8.6098  13.6104  5.7930  12.5173   0.5339
# 199999  train_199999  10.8762 -5.7105  12.1183  8.0328  11.5577   0.3488
#
#          var_6    var_7   var_8  ...  var_190  var_191  var_192  var_193  \
# ...

# %%
train_y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 199995    0
# 199996    0
# 199997    0
# 199998    0
# 199999    0
# Name: target, Length: 200000, dtype: int64

# %%
test
# Out:
#             ID_code    var_0    var_1    var_2   var_3    var_4    var_5  \
# 0            test_0  11.0656   7.7798  12.9536  9.4292  11.4327  -2.3805
# 1            test_1   8.5304   1.2543  11.3047  5.1858   9.1974  -4.0117
# 2            test_2   5.4827 -10.3581  10.1407  7.0479  10.2628   9.8052
# 3            test_3   8.5374  -1.3222  12.0220  6.5749   8.8458   3.1744
# 4            test_4  11.7058  -0.1327  14.1295  7.7506   9.1035  -8.5848
# ...             ...      ...      ...      ...     ...      ...      ...
# 199995  test_199995  13.1678   1.0136  10.4333  6.7997   8.5974  -4.1641
# 199996  test_199996   9.7171  -9.1462   7.3443  9.1421  12.8936   3.0191
# 199997  test_199997  11.6360   2.2769  11.2074  7.7649  12.6796  11.3224
# 199998  test_199998  13.5745  -0.5134  13.6584  7.4855  11.2241 -11.3037
# 199999  test_199999  10.4664   1.8070  10.2277  6.0654  10.0258   1.0789
#
#          var_6    var_7   var_8  ...  var_190  var_191  var_192  var_193  \
# ...
